# %%
import MDAnalysis as mda
from prolif import fingerprint, molecule
# Out:
# /home/bioc1870/Software/mambaforge/envs/md_env/lib/python3.12/site-packages/MDAnalysis/topology/tables.py:52: DeprecationWarning: Deprecated in version 2.8.0
# MDAnalysis.topology.tables has been moved to MDAnalysis.guesser.tables. This import point will be removed in MDAnalysis version 3.0.0
#   warnings.warn(wmsg, category=DeprecationWarning)

# %% [markdown]
# ### SLCO2A1 + PGF

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_PGF/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_PGF/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_PGF/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname UGU")

fp = fingerprint.Fingerprint.from_pickle(f'results/PGF/PGF_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="3940dc8319bd41b1b77b95107e3191be" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + P2E

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname P2E")

fp = fingerprint.Fingerprint.from_pickle(f'results/P2E/P2E_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="4faf286c126f404e9fcb7a65fbdb43fb" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + flipped P2E

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E_flipped/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E_flipped/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_P2E_flipped/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname P2E")

fp = fingerprint.Fingerprint.from_pickle(f'results/P2E_flipped/P2E_flipped_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="5b3e1007296641cbb2eaddebeb9c704a" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + FEN

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname FEN and not name LP*")

fp = fingerprint.Fingerprint.from_pickle(f'results/FEN/FEN_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="781333cb9ae24af4b5b6e0d896dec510" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + flipped FEN

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN_flipped/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN_flipped/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_FEN_flipped/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname FEN and not name LP*")

fp = fingerprint.Fingerprint.from_pickle(f'results/FEN_flipped/FEN_flipped_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="2ca13b5f6d8b46a5afb90bad3f1096e0" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + ZLK

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_ZLK/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_ZLK/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_ZLK/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname ZLK")

fp = fingerprint.Fingerprint.from_pickle(f'results/ZLK/ZLK_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="ce37222197894fe988c7cc4bba09dbf9" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + LSN

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_LSN/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_LSN/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_LSN/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname LSN and not name LP*")

fp = fingerprint.Fingerprint.from_pickle(f'results/LSN/LSN_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="104a71edb8fb477b9f557fcd8cf8e0ae" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...

# %% [markdown]
# ### SLCO2A1 + TCW

# %%
gro_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_TCW/production/rep_1/md.gro"  # To get the correct residue numbering
tpr_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_TCW/production/rep_1/md_system.tpr"
xtc_file = f"/home/bioc1870/SLCO2A1_simulations/RatSLCO2A1_TCW/analysis/md_all_center.xtc"

u = mda.Universe(tpr_file, xtc_file)
u_ref = mda.Universe(gro_file)
u.residues.resids = u_ref.residues.resids[:len(u.residues.resids)]  # Fix the residue numbering in u
ligand_sel = u.select_atoms("resname TCW")

fp = fingerprint.Fingerprint.from_pickle(f'results/TCW/TCW_ifp_all.pkl')
ligand_mol = molecule.Molecule.from_mda(ligand_sel,)
fp.plot_lignetwork(ligand_mol, threshold=0.5)
# Out:
# <iframe id="d2037255d31d4a05a3a62f02ab895778" width="100%" height="590px" frameborder="0" srcdoc="
#         &lt;html&gt;
#         &lt;head&gt;
#         &lt;script type=&quot;text/javascript&quot; src=&quot;https://unpkg.com/vis-network@9.0.4/dist/vis-network.min.js&quot;&gt;&lt;/script&gt;
#         &lt;link href=&quot;https://unpkg.com/vis-network@9.0.4/dist/dist/vis-network.min.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot; /&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#             body {
#                 padding: 0;
#                 margin: 0;
#                 background: #fff;
#             }
#             .legend-btn.residues.disabled {
#                 background: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#             .legend-btn.interactions.disabled {
#                 border-color: #b4b4b4 !important;
#                 color: #555 !important;
#             }
#         &lt;/style&gt;
# ...
